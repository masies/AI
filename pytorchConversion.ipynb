# %% [markdown]
# <a href="https://colab.research.google.com/github/masies/AI/blob/master/pytorchConversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import torch
# !pip3 install transformers
import transformers
# !pip install sentencepiece
import sentencepiece as spm

from google.colab import auth
auth.authenticate_user()
project_id = 'helical-loop-303918'
bucket_name = 'code_review_automation'

# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# ...
#      |████████████████████████████████| 1.8MB 5.4MB/s
# ...
#      |████████████████████████████████| 3.2MB 11.2MB/s
# ...
#      |████████████████████████████████| 890kB 48.3MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=4b3e817db221c69c7b89f96be3df79f506918376ef17a07f1702065f895702f1
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#      |████████████████████████████████| 1.2MB 4.3MB/s
# ...
# Updated property [core/project].
# gs://code_review_automation/
# gs://t5tutorial1/

# %%
# !gsutil cp gs://{bucket_name}/pyTorch_coversion/code/tf_2_pytorch_T5.py ./tf_2_pytorch_T5.py

! mkdir models
! mkdir dumps

# !gsutil cp gs://{bucket_name}/model_dumps/model.ckpt-275000.index ./models/model.ckpt-275000.index
# !gsutil cp gs://{bucket_name}/model_dumps/model.ckpt-275000.meta ./models/model.ckpt-275000.meta
# !gsutil cp gs://{bucket_name}/model_dumps/model.ckpt-275000.data-00000-of-00002 ./models/model.ckpt-275000.data-00000-of-00002
# !gsutil cp gs://{bucket_name}/model_dumps/model.ckpt-275000.data-00001-of-00002 ./models/model.ckpt-275000.data-00001-of-00002

# !gsutil cp gs://{bucket_name}/pyTorch_coversion/config/config.json ./config.json
# Out:
# Copying gs://code_review_automation/pyTorch_coversion/code/tf_2_pytorch_T5.py...
# / [1 files][  2.3 KiB/  2.3 KiB]
# Operation completed over 1 objects/2.3 KiB.
# Copying gs://code_review_automation/model_dumps/model.ckpt-275000.index...
# / [1 files][  5.5 KiB/  5.5 KiB]
# Operation completed over 1 objects/5.5 KiB.
# Copying gs://code_review_automation/model_dumps/model.ckpt-275000.meta...
# / [1 files][  9.0 MiB/  9.0 MiB]
# Operation completed over 1 objects/9.0 MiB.
# Copying gs://code_review_automation/model_dumps/model.ckpt-275000.data-00000-of-00002...
# / [1 files][    8.0 B/    8.0 B]
# Operation completed over 1 objects/8.0 B.
# Copying gs://code_review_automation/model_dumps/model.ckpt-275000.data-00001-of-00002...
# \
# Operation completed over 1 objects/99.4 MiB.
# Copying gs://code_review_automation/pyTorch_coversion/config/config.json...
# / [1 files][  463.0 B/  463.0 B]
# Operation completed over 1 objects/463.0 B.

# %%
# !python3 ./tf_2_pytorch_T5.py --tf_checkpoint_path ./models/model.ckpt-275000 --config_file ./config.json --pytorch_dump_path ./dumps
# Out:
# Building PyTorch model from configuration: T5Config {
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "transformers_version": "4.3.2",
#   "use_cache": true,
#   "vocab_size": 15104
# }
#
# 2021-02-15 17:21:17.560634: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Converting TensorFlow checkpoint from /content/models/model.ckpt-275000
# Loading TF weight decoder/block_000/layer_000/SelfAttention/k with shape [512, 512]
# ...

# %%
# !gsutil cp gs://{bucket_name}/pyTorch_coversion/code/validation.py ./validation.py
# !mkdir core
# !mkdir core/__pycache__

# !gsutil -m cp -r \
  "gs://code_review_automation/pyTorch_coversion/core/Logger.py" \
  "gs://code_review_automation/pyTorch_coversion/core/__init__.py" \
  "gs://code_review_automation/pyTorch_coversion/core/custom_dataset.py" \
  ./core/

# !gsutil -m cp \
  "gs://code_review_automation/pyTorch_coversion/core/__pycache__/Logger.cpython-38.pyc" \
  "gs://code_review_automation/pyTorch_coversion/core/__pycache__/__init__.cpython-38.pyc" \
  ./core/__pycache__

# !gsutil cp gs://{bucket_name}/models/TestModel.model ./TestModel.model
# !gsutil cp gs://{bucket_name}/vocab/TestModel.vocab ./TestModel.vocab
# Out:
# ServiceException: 401 Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object.
# CommandException: 1 file/object could not be transferred.
# ServiceException: 401 Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object.
# CommandException: 1 file/object could not be transferred.
# BadRequestException: 400 Invalid bucket name: '{bucket_name}'
# BadRequestException: 400 Invalid bucket name: '{bucket_name}'

# %%
# !gsutil cp ./dumps/pytorch_model.bin gs://code_review_automation/pyTorch_coversion/pyTorch_dumps/pytorch_model.bin

# %%
# model = torch.load("./dumps/pytorch_model.bin")

# %%
# !python3 newVal.py --beam_size 2 --batch_size 2 --data_dir ./data/ --tokenizer_name ./TestModel.model --model_name_or_path ./dumps/pytorch_model.bin --config_name ./config.json
# Out:
# Calling T5Tokenizer.from_pretrained() with the path to a single file or url is deprecated
# ...

# %%
# !cat ./results.txt
# !rm ./results.txt
# Out:
# [+] Input: public static void <extra_id_0>(String[] args) {System.Out.println("hello world")}
# [+] Target: main
# 	 [-] pred: hello world world world<hello world world world<extra_idididididididididididididididididid
# 	 [-] pred: hello world world world<hello world world world<extra_ididididididididididididididididid<
# [+] Input: public static void main(String[] <extra_id_0> {System.Out.println("hello world")}
# [+] Target: args)
# 	 [-] pred: hello world@paramparamparamparam<<363636363636363636363636363636363636363636
# 	 [-] pred: hello world@paramparamparamparam<<<  363636363636363636363636363636363636
# [+] Input: public static void main(String[] args) {System.Out.<extra_id_0>("hello world")}
# [+] Target: println
# 	 [-] pred: printlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintlnprintln
# ...
